# %%
import pandas as pd

# %%
# Path to your EVAL.xlsx file
EVAL_PATH = "model/EVAL.xlsx"

# Load the Excel file into a pandas DataFrame
df = pd.read_excel(EVAL_PATH)

# Display the entire DataFrame
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', None)  # Remove column width limit
pd.set_option('display.colheader_justify', 'left')  # Justify column headers

print(df)
# Out:
#     ID  IMG_SIZE VARIANT HEAD_ARCH             PARAM_COUNT  BATCH_SIZE  EPC  \
# 0   51  384       VANILA        640 → 512 → 9  332288       32          20
# 1   71  384       VANILA        640 → 512 → 9  332288       32          20
# 2   72  224       VANILA        640 → 256 → 9  165000       32          20
# 3   73  224       VANILA        640 → 256 → 9  165000       64          20
# 4   74  224       VANILA  640 → 256 → 128 → 9  197760       32          20
# 5   75  224       VANILA  640 → 256 → 128 → 9  197760       32          20
# 6   61  224       VANILA        640 → 256 → 9  197760       96          30
# 7   61  224       VANILA        640 → 256 → 9  197760       96          30
# 8   62  224          6ch        640 → 256 → 9  165000       48          25
# 9   76  224          6ch  640 → 256 → 128 → 9  197760       96          25
# 10  63  224          6ch        640 → 256 → 9  197760       96          30
# ...
